# %%
import pandas as pd
import seaborn as s

# %%
df = pd.read_csv("./Data/train.csv")

# %%
df
# Out:
#         id  protected                                              Title  \
# 0        1      54622                                           Accounts
# 1        2   27305950                                     Graphic Design
# 2        3   22681506                                     Graphic Design
# 3        4   57706912                                          Marketing
# 4        5      43990                                           Accounts
# ...    ...        ...                                                ...
# 8513  8514  127340040                  The Young Conservationist Program
# 8514  8515   26951772                                     Graphic Design
# 8515  8516   29057590                                Illustration Design
# 8516  8517     740560                                           Unity 3D
# 8517  8518   52860270  Business Development (Seasonings For Snacks In...
#
#                                                 Company        Location  \
# ...

# %%
df = pd.read_pickle('keywords.pkl')
# df.keys()
len(df['Graphic Design'])
# Out:
# 75

# %%
list = []
# for i in range(len(di))
def jsony(df):
    jsoni = dict()
    for i in df.keys():
    #     print(type(i))
        jsoni['tag'] = i
        jsoni['pattern'] = df[i]
        jsoni['response']= i
        
    return jsoni

# %%
from pprint import pprint
j = 0
listy = [{'tag': i ,'pattern':df[i],'respone':i} for i in df.keys()]
# for i in listy:
#     i['pattern'] = list
# while j < len(df.keys()):
#     jsoni = dict()
#     jsoni['tag'] = j
#     jsoni['pattern'] = df[j]
#     jsoni['response']= j
#     listy.append(jsoni)
#     j+=1

pprint(listy)
# Out:
# [{'pattern': {'account',
#               'accountsfin',
#               'analysi',
#               'art',
#               'articleship',
#               'assist',
#               'audit',
#               'bank',
#               'bookkeep',
#               'catalog',
#               'catalogu',
#               'charter',
#               'commerc',
#               'content',
#               'core',
#               'doubt',
#               'ecommerc',
#               'econom',
#               'execut',
#               'expert',
#               'financ',
#               'financi',
#               'intern',
#               'invest',
#               'logist',
#               'macroeconom',
#               'manag',
#               'market',
#               'matter',
#               'microeconom',
#               'oper',
#               'purchas',
#               'servic',
#               'solv',
#               'stock',
#               'subject',
#               'supervis',
# ...

# %%
import json
dicty = dict()
dicty['intents'] = listy
# pprint(dicty)
with open("internship.json", "w") as outfile:
    json.dump(dicty, outfile)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-28-433af51117d8> in <module>
#       4 # pprint(dicty)
#       5 with open("internship.json", "w") as outfile:
# ----> 6     json.dump(dicty, outfile)
#
# c:\users\91703\anaconda3\lib\json\__init__.py in dump(obj, fp, skipkeys, ensure_ascii, check_circular, allow_nan, cls, indent, separators, default, sort_keys, **kw)
#     177     # could accelerate with writelines in some versions of Python, at
#     178     # a debuggability cost
# --> 179     for chunk in iterable:
#     180         fp.write(chunk)
#     181
#
# c:\users\91703\anaconda3\lib\json\encoder.py in _iterencode(o, _current_indent_level)
#     429             yield from _iterencode_list(o, _current_indent_level)
#     430         elif isinstance(o, dict):
# --> 431             yield from _iterencode_dict(o, _current_indent_level)
# ...
